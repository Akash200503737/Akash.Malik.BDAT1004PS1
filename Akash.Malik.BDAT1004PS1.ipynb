# %% [markdown]
# Question 1 C#
# What data type is each of the following?

# %%
5         ----> Int
5.0       ----> Float
5 > 1     ----> Bool
'5'       ----> Str
5 * 2     ----> Int
'5' * 2   ----> Str
'5' + '2' ----> Str
5 / 2     ----> Float
5 % 2     ----> Int
{5, 2, 1} ----> Int
5 == 3    ----> Bool
Pi (the number)---->Float

# %% [markdown]
# Question 2 C#
# Write (and evaluate) C# expressions that answer these questions:
# a. How many letters are there in 'Supercalifragilisticexpialidocious'?
# b. Does 'Supercalifragilisticexpialidocious' contain 'ice' as a substring?
# c. Which of the following words is the longest:
# Supercalifragilisticexpialidocious, Honorificabilitudinitatibus, or
# Bababadalgharaghtakamminarronnkonn?
# d. Which composer comes first in the dictionary: 'Berlioz', 'Borodin', 'Brian',
# 'Bartok', 'Bellini', 'Buxtehude', 'Bernstein'. Which one comes last?

# %%
using System;
using System.Collections.Generic;
using System.Linq;
class question2
{
    static void Main()
    {
        //a
        // count the letters in 'Supercalifragilisticexpialidocious'
        string letters = "Supercalifragilisticexpialidocious";
        int count = letters.Length;
        Console.WriteLine("{0} letters", count);

        //b
        //verifies 'Supercalifragilisticexpialidocious' contain 'ice' as a substring or not
        bool i = letters.Contains("ice");
        Console.WriteLine("'{0}' is in the string '{1}': {2}", "ice", letters, i);

        //c
        // check which word is longest on basis of its character length
        string letters2 = "Honorificabilitudinitatibus";
        string letters3 = "Bababadalgharaghtakamminarronnkonn";
        //comapring lenghts of words
        if (letters.Length > letters2.Length && letters.Length > letters3.Length)
            Console.WriteLine("{0} is the largest.", letters);
        else if (letters2.Length > letters.Length && letters2.Length > letters3.Length)
            Console.WriteLine("{0} is the largest.", letters2);
        else if (letters3.Length > letters.Length && letters3.Length > letters2.Length)
            Console.WriteLine("{0} is the largest.", letters3);
        else
           if (letters.Length == letters2.Length && letters.Length > letters3.Length)
        {
            Console.WriteLine("Supercalifragilisticexpialidocious and Honorificabilitudinitatibus are the largest.");
        }
        else if (letters2.Length == letters3.Length && letters2.Length > letters.Length)
        {
            Console.WriteLine("Honorificabilitudinitatibus and Bababadalgharaghtakamminarronnkonn are the largest.");
        }
        else if (letters3.Length == letters.Length && letters2.Length < letters.Length)
        {
            Console.WriteLine("Bababadalgharaghtakamminarronnkonn and Supercalifragilisticexpialidocious are the largest.");
        }

        //d
        //creating a dictionary with values provided and sorting to check which composer comes first and last. 
        var dict = new Dictionary<int, string>
        {
            {1,"Berlioz" },{2,"Borodin"},{3,"Brian"},{4,"Bartok"},{5,"Buxtehude"},{6,"Bernstein"}
        };
        var templist = dict.ToList();
        templist.Sort((i, j) => i.Value.CompareTo(j.Value));
        Console.WriteLine(templist.First());
        Console.WriteLine(templist.Last());
    }
}

# %% [markdown]
# ![q2.png](attachment:q2.png)

# %% [markdown]
# Question 3 C#
# Implement function triangleArea(a,b,c) that takes as input the lengths of the 3
# sides of a triangle and returns the area of the triangle. By Heron's formula, the area
# of a triangle with side lengths a, b, and c is
# s(s - a)(s -b)(s -c)
# , where
# s = (a+b+c)/2.
# >>> triangleArea(2,2,2)
# 1.7320508075688772

# %%
using System;
using System.Collections.Generic;
class question3
{
    static void Main()
    {
        int a, b, c;
        double triangleArea;
        int s;
        a = 2;
        b = 2;
        c = 2;
        s = (a + b + c) / 2;
        //calculate area of traingle
        triangleArea = Math.Sqrt(s * (s - a) * (s - b) * (s - c));
        Console.WriteLine("{0}", triangleArea);
    }
}

# %% [markdown]
# ![q3.png](attachment:q3.png)

# %% [markdown]
# Question 4 C#
# Write a program in C# Sharp to separate odd and even integers in separate arrays.
# Go to the editor
# Test Data :
# Input the number of elements to be stored in the array :5
# Input 5 elements in the array :
# element - 0 : 25
# element - 1 : 47
# element - 2 : 42
# element - 3 : 56
# element - 4 : 32
# Expected Output:
# The Even elements are:
# 42 56 32
# The Odd elements are :
# 25 47

# %%
using System;
using System.Collections.Generic;
class question4
{

    public static void Main()
    {
        //initialize variables that store input elements
        int e0, e1, e2, e3, e4;
        int e;
        Console.WriteLine("Input the number of elements to be stored in the array :");
        e = Convert.ToInt32(Console.ReadLine());
        //create list which stores all, even, odd elements respectively
        List<int> elements = new List<int>(e);
        List<int> even = new List<int>();
        List<int> odd = new List<int>();
        //taking user input and assigning it to variables
        Console.WriteLine("Input 5 elements in the array :");
        Console.WriteLine("Element - 0 :");
        e0 = Convert.ToInt32(Console.ReadLine());

        Console.WriteLine("Element - 1 :");
        e1 = Convert.ToInt32(Console.ReadLine());

        Console.WriteLine("Element - 2 :");
        e2 = Convert.ToInt32(Console.ReadLine());

        Console.WriteLine("Element - 3 :");
        e3 = Convert.ToInt32(Console.ReadLine());

        Console.WriteLine("Element - 4");
        e4 = Convert.ToInt32(Console.ReadLine());
        elements.Add(e0);
        elements.Add(e1);
        elements.Add(e2);
        elements.Add(e3);
        elements.Add(e4);
        //looping the list of elements to find even and odd elements
        foreach (int i in elements)
        {
            if (i % 2 == 0)
            {
                even.Add(i);
            }

            else
            {
                odd.Add(i);
            }
        }
        //print the even and odd list
        Console.WriteLine("The Even Elements are : {0}", String.Join(" ", even));
        Console.WriteLine("The Odd Elements are : {0}", String.Join(" ", odd));
    }
}

# %% [markdown]
# ![q4.png](attachment:q4.png)

# %% [markdown]
# Question 5 C#
# a. Write a function inside(x,y,x1,y1,x2,y2) that returns True or False
# depending on whether the point (x,y) lies in the rectangle with lower left
# corner (x1,y1) and upper right corner (x2,y2).
# >>> inside(1,1,0,0,2,3)
# True
# >>> inside(-1,-1,0,0,2,3)
# False
# b. Use function inside() from part a. to write an expression that tests whether
# the point (1,1) lies in both of the following rectangles: one with lower left
# corner (0.3, 0.5) and upper right corner (1.1, 0.7) and the other with lower
# left corner (0.5, 0.2) and upper right corner (1.1, 2).

# %%
using System;
using System.Collections.Generic;
class question5
{
    //initializing variables to store point values
    static bool inside(float x,float y, float x1, float y1, float x2,float y2)
    {
        //checking the x,y lies between x1,y1 and x2,y2
        if (x > x1 && x < x2 && y > y1 && y < y2)
        {
            return true;
        }
        else
        {
            return false;
        }
    }
    public static void Main()
    {
        //taking input from user and storing it to variables
        float x, x1, y, y1, x2, y2;
        Console.WriteLine("Enter the value of x");
        x = Single.Parse(Console.ReadLine());

        Console.WriteLine("Enter the value of y");
        y = Single.Parse(Console.ReadLine());

        Console.WriteLine("Enter the value of x1:");
        x1 = Single.Parse(Console.ReadLine());

        Console.WriteLine("Enter the value of y1:");
        y1 = Single.Parse(Console.ReadLine());

        Console.WriteLine("Enter the value of x2:");
        x2 = Single.Parse(Console.ReadLine());

        Console.WriteLine("Enter the value of y2:");
        y2 = Single.Parse(Console.ReadLine());

        // calling inside function
        if (inside(x, y, x1, y1, x2, y2))
        {
            Console.WriteLine("True");
        }
        else
        {
            Console.WriteLine("False");
        }
    }
}

# %% [markdown]
# ![q5a.png](attachment:q5a.png)

# %% [markdown]
# ![q5b.png](attachment:q5b.png)

# %% [markdown]
# Question 6 Python
# 16. You can turn a word into pig-Latin using the following two rules (simplified):
# • If the word starts with a consonant, move that letter to the end and append
# 'ay'. For example, 'happy' becomes 'appyhay' and 'pencil' becomes 'encilpay'.
# • If the word starts with a vowel, simply append 'way' to the end of the word.
# For example, 'enter' becomes 'enterway' and 'other' becomes 'otherway' . For
# our purposes, there are 5 vowels: a, e, i, o, u (so we count y as a consonant).
# Write a function pig() that takes a word (i.e., a string) as input and returns its pigLatin form. Your function should still work if the input word contains upper case
# characters. Your output should always be lower case however.
# >>> pig('happy')
# 'appyhay'
# >>> pig('Enter')
# 'enterway'

# %%
def pig(i):
    #i as input string
    i=i.lower()
    #checking that the 0th index element is a vowel or not.
    if (i[0] not in "aeiou" ):
        #taking first element in a variable
        temp=i[0]
        #adding first char+"ay" in end
        i=i+temp+"ay"
        #removing 0th char
        i=i[1::]

        print(i)
    else:
        #if word starts with vowel, adding "way" in end
        i=i+"way"
        print(i)
pig(i=input("Enter a string:"))
# Out:
# Enter a string:Enter
# enterway

# %% [markdown]
# Question 7 Python
# File bloodtype1.txt records blood-types of patients (A, B, AB, O or OO) at a clinic.
# Write a function bldcount() that reads the file with name name and reports (i.e.,
# prints) how many patients there are in each bloodtype.
# >>> bldcount('bloodtype.txt')
# There are 10 patients of blood type A.
# There is one patient of blood type B.
# There are 10 patients of blood type AB.
# There are 12 patients of blood type O.
# There are no patients of blood type OO.

# %%
def bldcount(name):
    l=[]
    temp = open(name, "r") 
    l=temp.read() #read the bloodtest file and store into list
    #List down all blood types
    btype=[' A ',' B ',' AB ',' O ',' OO '] #btype as bloodtype
    for t in btype:
        if l.count(t) > 1:
            print("There are "+str(l.count(t))+"  patients of blood type" +t+".")  #If there are many patient of blood type
        elif l.count(t) == 1:
            print("There is one patient of blood type" +t+".") #If there is 1 patient of blood type
        else:
            print("There is no patient of blood type" +t+".") #If there is no patient of blood type
    
bldcount("C:\\Users\\Akii Malik\\Desktop\\bloodtest1.txt")
# Out:
# There are 10  patients of blood type A .
# There is one patient of blood type B .
# There are 10  patients of blood type AB .
# There are 12  patients of blood type O .
# There is no patient of blood type OO .

# %% [markdown]
# Question 8 Python
# Write a function curconv() that takes as input:
# 1. a currency represented using a string (e.g., 'JPY' for the Japanese Yen or
# 'EUR' for the Euro)
# 2. an amount
# and then converts and returns the amount in US dollars.
# >>> curconv('EUR', 100)
# 122.96544
# >>> curconv('JPY', 100)
# 1.241401
# The currency rates you will need are stored in file currencies.txt:
# AUD 1.0345157 Australian Dollar
# CHF 1.0237414 Swiss Franc
# CNY 0.1550176 Chinese Yuan
# DKK 0.1651442 Danish Krone
# EUR 1.2296544 Euro
# GBP 1.5550989 British Pound
# HKD 0.1270207 Hong Kong Dollar
# INR 0.0177643 Indian Rupee
# JPY 0.01241401 Japanese Yen
# MXN 0.0751848 Mexican Peso
# MYR 0.3145411 Malaysian Ringgit
# NOK 0.1677063 Norwegian Krone
# NZD 0.8003591 New Zealand Dollar
# PHP 0.0233234 Philippine Peso
# SEK 0.148269 Swedish Krona
# SGD 0.788871 Singapore Dollar
# THB 0.0313789 Thai Baht

# %%
def curconv(i,j):
    i=i.upper() #chaning input to Upper case
    
    #checking the input currency and converting it to USD.
    if i=='AUD' or i=='AUSTRALIAN DOLLAR':
        j=j*1.0345157
        print(j)
    if i=='CHF'or i=='SWISS FRANC':
        j=j*1.0237414
        print(j)
    if i=='CNY'or i=='CHINESE YUAN':
        j=j*0.1550176
        print(j)
    if i=='DKK'or i=='DANISH KRONE':
        j=j*0.1651442
        print(j)
    if i=='EUR'or i=='EURO':
        j=j*1.2296544
        print(j)
    if i=='GBP'or i=='BRITISH POUND':
        j=j*1.5550989
        print(j)
    if i=='HKD'or i=='HONG KONG DOLLAR':
        j=j*0.1270207
        print(j)
    if i=='INR'or i=='INDIAN RUPEE':
        j=j*0.0177643
        print(j)
    if i=='JPY'or i=='JAPANESE YEN':
        j=j*0.01241401
        print(j)
    if i=='MXN' or i=='MEXICAN PESO':
        j=j*0.0751848
        print(j)
    if i=='MYR'or i=='MALAYSIAN RINGGIT':
        j=j*0.3145411
        print(j)
    if i=='NOK'or i=='NORWEGIAN KRONE':
        j=j*0.1677063
        print(j)
    if i=='NZD' or i=='NEW ZEALAND DOLLAR':
        j=j*0.8003591
        print(j)
    if i=='PHP' or i=='PHILIPPINE PESO':
        j=j*0.0233234
        print(j)
    if i=='SEK'or i=='SWEDISH KRONA':
        j=j*0.148269
        print(j)
    if i=='SGD' or i=='SINGAPORE DOLLAR':
        j=j*0.788871
        print(j)
    if i=='THB' or i=='THAI BAHT':
        j=j*0.0313789
        print(j)

curconv(input("Enter currency: "), float(input("Enter value: ")))
# Out:
# Enter currency: euro
# Enter value: 100
# 122.96544

# %% [markdown]
# Question 9 Python
# Each of the following will cause an exception (an error). Identify what type of
# exception each will cause.
# Trying to add incompatible variables, as in
# adding 6 + ‘a’
# Referring to the 12th item of a list that has only 10
# items
# Using a value that is out of range for a function’s
# input, such as calling math.sqrt(-1.0)
# Using an undeclared variable, such as print(x)
# when x has not been defined
# Trying to open a file that does not exist, such as
# mistyping the file name or looking in the wrong
# directory.

# %%
incval=6+'a'
#Type Error : If we try to add 2 diff data type values.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-bdf40361c085> in <module>
# ----> 1 incval=6+'a'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
l=[1,2,3,4,5,6,7,8,9,0]
i=l[12]
#IndexError : If the index is out of range of list
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-b20f5e36b401> in <module>
#       1 l=[1,2,3,4,5,6,7,8,9,0]
# ----> 2 i=l[12]
#
# IndexError: list index out of range

# %%
import math
temp=math.sqrt(-1.0)
#ValueError : If the value is not as per the function
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-29bb36d94f4d> in <module>
#       1 import math
# ----> 2 temp=math.sqrt(-1.0)
#
# ValueError: math domain error

# %%
print(x)
#NameError : If the variable is not defined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-fc17d851ef81> in <module>
# ----> 1 print(x)
#
# NameError: name 'x' is not defined

# %%
temp = open("C:\\Users\\Akii Malik\\Desktop\\bloodtes1.txt", "r")
#FileNotFoundError : If the file is not present on the path
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-99af1da1a7b0> in <module>
# ----> 1 temp = open("C:\\Users\\Akii Malik\\Desktop\\bloodtes1.txt", "r")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Akii Malik\\Desktop\\bloodtes1.txt'

# %% [markdown]
# Question 10 Python
# Encryption is the process of hiding the meaning of a text by substituting letters in the
# message with other letters, according to some system. If the process is successful, no
# one but the intended recipient can understand the encrypted message. Cryptanalysis
# refers to attempts to undo the encryption, even if some details of the encryption are
# unknown (for example, if an encrypted message has been intercepted). The first step
# of cryptanalysis is often to build up a table of letter frequencies in the encrypted text.
# Assume that the string letters is already defined as
# 'abcdefghijklmnopqrstuvwxyz'. Write a function called frequencies()
# that takes a string as its only parameter, and returns a list of integers, showing the
# number of times each character appears in the text. Your function may ignore any
# characters that are not in letters.
# >>> frequencies('The quick red fox got bored and went home.')
# [1, 1, 1, 3, 5, 1, 1, 2, 1, 0, 1, 0, 1, 2, 4, 0, 1, 2, 0, 2,
# 1, 0, 1, 1, 0, 0]
# >>> frequencies('apple')

# %%
def frequencies(i):
    #i as input string
    str='abcdefghijklmnopqrstuvwxyz'
    l=[]
    #looping in alphabets to check the count of no. of alphabets in input string
    for t in str:
        #adding count to list
        l.append(i.count(t))
    print(l)
frequencies(str(input("Enter string to be encrypted: ")))
# Out:
# Enter string to be encrypted: The quick red fox got bored and went home.
# [1, 1, 1, 3, 5, 1, 1, 2, 1, 0, 1, 0, 1, 2, 4, 0, 1, 2, 0, 2, 1, 0, 1, 1, 0, 0]
